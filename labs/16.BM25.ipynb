# %%
from langchain_core.documents import Document
from langchain_community.retrievers import BM25Retriever
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_4360\2189965384.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import BM25Retriever

# %%
texts = [
    "The quick brown fox jumps over the lazy dog.",

    "Apple releases the new iPhone 15 Pro Max with 256GB storage.",

    "Error code ERR-9021 indicates a database connection failure.",

    "A database is an organized collection of data.",

    "The new Apple MacBook Pro is great for developers."
]

docs = [
    Document(page_content=text)
    for text in texts
]

# %%
retriever = BM25Retriever.from_documents(docs)

retriever.k = 2

# %%
query = "ERR-9021"

print("Query:", query)

results = retriever.invoke(query)

for i, doc in enumerate(results, start=1):
    print(f"\nRank {i}")
    print(doc.page_content)
# Out:
# Query: ERR-9021
#
# Rank 1
# Error code ERR-9021 indicates a database connection failure.
#
# Rank 2
# The new Apple MacBook Pro is great for developers.

# %%
query = "iPhone 15 storage"

print("Query:", query)

results = retriever.invoke(query)

for i, doc in enumerate(results, start=1):
    print(f"\nRank {i}")
    print(doc.page_content)
# Out:
# Query: iPhone 15 storage
#
# Rank 1
# Apple releases the new iPhone 15 Pro Max with 256GB storage.
#
# Rank 2
# The new Apple MacBook Pro is great for developers.
